# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("CIA_Country_Facts.csv")
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# #### EDA:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
sns.histplot(data = df[df["Population"] < 50000000 ], x = "Population")
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.histplot(data = df, x = "Population")
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
sns.barplot(data= df, y = "GDP ($ per capita)", x = "Region", estimator=np.mean)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(data= df, x = "GDP ($ per capita)", y = "Literacy (%)", hue = "Region")
# Out:
# <Axes: xlabel='GDP ($ per capita)', ylabel='Literacy (%)'>

# %% [markdown]
# ####  Missing data

# %%
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df.groupby('Region')["Literacy (%)"].transform('mean')
# Out:
# 0      79.553571
# 1      97.088889
# 2      67.240000
# 3      88.835294
# 4      98.391304
#          ...
# 222    79.521429
# 223    67.240000
# 224    79.521429
# 225    62.510000
# 226    62.510000
# Name: Literacy (%), Length: 227, dtype: float64

# %%
df.tail(2)
# Out:
#       Country                               Region  Population  \
# 225    Zambia  SUB-SAHARAN AFRICA                     11502010
# 226  Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 225          752614                        15.3                           0.0
# 226          390580                        31.3                           0.0
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 225            0.0                               88.29               800.0
# 226            0.0                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# ...

# %%
# Replaced the missing value with the ave literacy rate in that region
df["Literacy (%)"] = df["Literacy (%)"].fillna(df.groupby('Region')["Literacy (%)"].transform('mean'))

# %%
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                           0
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df.head()
# Out:
#              Country                               Region  Population  \
# 0        Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1            Albania  EASTERN EUROPE                          3581655
# 2            Algeria  NORTHERN AFRICA                        32930091
# 6           Anguilla              LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda              LATIN AMER. & CARIB           69108
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 6             102                       132.1                         59.80
# 7             443                       156.0                         34.54
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
X = df.drop("Country", axis = 1)
X = pd.get_dummies(X)
X.head()
# Out:
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    31056997          647500                        48.0
# 1     3581655           28748                       124.6
# 2    32930091         2381740                        13.8
# 6       13477             102                       132.1
# 7       69108             443                       156.0
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                          0.00          23.06
# 1                          1.26          -4.93
# 2                          0.04          -0.39
# 6                         59.80          10.76
# 7                         34.54          -6.15
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                              163.07               700.0          36.0
# 1                               21.52              4500.0          86.5
# 2                               31.00              6000.0          70.0
# ...

# %%
#Scale this data 
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc_X = sc.fit_transform(X) # Scaled X

# %%
# sc_X

# %%
from sklearn.cluster import KMeans

# %%
# To get the optimum num of clusters. 
ssd = []
for k in range(2, 16):
    model = KMeans(n_clusters=k)
    model.fit(sc_X)

    ssd.append(model.inertia_)

# %%
plt.plot(range(2,16), ssd, 'o--', mfc = 'red')
plt.xlabel("K value")
plt.ylabel("Sum of Squares of Distance")
# Out:
# Text(0, 0.5, 'Sum of Squares of Distance')

# %%
pd.Series(ssd).diff().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Now Train the model with three cluster.

# %%
model = KMeans(n_clusters=3)
model.fit(sc_X)
# Out:
# KMeans(n_clusters=3)

# %%
X['K=3'] = model.labels_

# %%
X.corr()['K=3']
# Out:
# Population                                   -0.075667
# Area (sq. mi.)                                0.063733
# Pop. Density (per sq. mi.)                    0.228551
# Coastline (coast/area ratio)                  0.313560
# Net migration                                 0.036736
# Infant mortality (per 1000 births)            0.412958
# GDP ($ per capita)                           -0.195250
# Literacy (%)                                 -0.326141
# Phones (per 1000)                            -0.305987
# Arable (%)                                   -0.186725
# Crops (%)                                     0.212342
# Other (%)                                     0.035895
# Climate                                      -0.269512
# Birthrate                                     0.440123
# Deathrate                                     0.264470
# Agriculture                                   0.375422
# Industry                                     -0.228308
# ...

# %%
labels = model.predict(sc_X)
df["cluster"] = labels
df.groupby("cluster").mean(numeric_only=True)
# Out:
#            Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# cluster
# 0        4.062079e+07   496022.690265                  189.500885
# 1        2.128338e+07   480926.298246                   86.503509
# 2        1.689269e+07   884440.300000                 1633.620000
#
#          Coastline (coast/area ratio)  Net migration  \
# cluster
# 0                            8.624956      -0.347965
# 1                            0.986842       0.101579
# 2                          114.149500      -0.026000
#
#          Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# cluster
# 0                                 17.997522        11961.946903     91.445546
# 1                                 83.137544         1938.596491     61.264912
# 2                                 19.017500        13270.000000     92.340294
#
#          Phones (per 1000)  Arable (%)  Crops (%)  Other (%)   Climate  \
# cluster
# ...

# %% [markdown]
# This is unsupervised learning, so there are no labels.
# We train the model using the data to find cluster centroids.
# After training, the model groups the data into three clusters.
# We then interpret the meaning of each cluster based on the features of the data points in that cluster.
# When new data arrives, we use the same trained model to predict which cluster it belongs to.
# Based on the previous interpretation of that cluster, we can infer the likely characteristics of the new data.

# %%
# Find which cluster has the highest value for each feature 
cluster_mean = df.groupby("cluster").mean(numeric_only=True)
cluster_mean.idxmax()
# Out:
# Population                            0
# Area (sq. mi.)                        2
# Pop. Density (per sq. mi.)            2
# Coastline (coast/area ratio)          2
# Net migration                         1
# Infant mortality (per 1000 births)    1
# GDP ($ per capita)                    2
# Literacy (%)                          2
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             2
# Other (%)                             1
# Climate                               0
# Birthrate                             1
# Deathrate                             1
# Agriculture                           1
# Industry                              0
# Service                               2
# dtype: int32

# %%
cluster_mean.idxmin()
# Out:
# Population                            2
# Area (sq. mi.)                        1
# Pop. Density (per sq. mi.)            1
# Coastline (coast/area ratio)          1
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    1
# Literacy (%)                          1
# Phones (per 1000)                     1
# Arable (%)                            2
# Crops (%)                             1
# Other (%)                             2
# Climate                               1
# Birthrate                             0
# Deathrate                             2
# Agriculture                           0
# Industry                              2
# Service                               1
# dtype: int32

# %%
cluster_mean
# Out:
#            Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# cluster
# 0        4.062079e+07   496022.690265                  189.500885
# 1        2.128338e+07   480926.298246                   86.503509
# 2        1.689269e+07   884440.300000                 1633.620000
#
#          Coastline (coast/area ratio)  Net migration  \
# cluster
# 0                            8.624956      -0.347965
# 1                            0.986842       0.101579
# 2                          114.149500      -0.026000
#
#          Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# cluster
# 0                                 17.997522        11961.946903     91.445546
# 1                                 83.137544         1938.596491     61.264912
# 2                                 19.017500        13270.000000     92.340294
#
#          Phones (per 1000)  Arable (%)  Crops (%)  Other (%)   Climate  \
# cluster
# ...
