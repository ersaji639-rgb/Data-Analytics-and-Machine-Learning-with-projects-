# %% [markdown]
# ### Number guessing game

# %% [markdown]
# The computer randomly chooses a number between 1 and 100.
# You (the player) try to guess it.
# It gives hints like "Too high" or "Too low" until you get it right.

# %%
import random

def guessing_game():
    number = random.randint(1, 100)  # secret number
    attempts = 0

    print("I'm thinking of a number between 1 and 100. Can you guess it?")

    while True:
        guess = input("Enter your guess: ")

        # check if the input is a number
        if not guess.isdigit():
            print("Please enter a valid number.")
            continue

        guess = int(guess)
        attempts += 1

        if guess < number:
            print("Too low! Try again.")
        elif guess > number:
            print("Too high! Try again.")
        else:
            print(f"🎉 Congratulations! You guessed it in {attempts} attempts.")
            break

guessing_game()
# Out:
# I'm thinking of a number between 1 and 100. Can you guess it?
# Enter your guess:  5
# Too low! Try again.
# Enter your guess:  50
# Too high! Try again.
# Enter your guess:  3
# Too low! Try again.
# Enter your guess:  70
# Too high! Try again.
# Enter your guess:  53
# Too high! Try again.
# Enter your guess:  25
# Too low! Try again.
