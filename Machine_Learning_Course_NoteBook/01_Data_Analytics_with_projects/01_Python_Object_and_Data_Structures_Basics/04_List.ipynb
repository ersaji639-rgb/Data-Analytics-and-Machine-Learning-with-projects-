# %% [markdown]
# # Creating a list
# my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
type(my_list)
# Out:
# list

# %%
my_list1 = [' A string', 23, 1.2, 'o',' ']

# %%
my_list1
# Out:
# [' A string', 23, 1.2, 'o', ' ']

# %%
len(my_list1)
# Out:
# 5

# %% [markdown]
# ####  Indexing and slixing

# %%
my_list1 = ['one', 'two','three',4,5]

# %%
my_list1
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
my_list1[0]
# Out:
# 'one'

# %%
len(my_list1)
# Out:
# 5

# %%
my_list1[-1]
# Out:
# 5

# %%
type(my_list1)
# Out:
# list

# %%
type(my_list1[0])
# Out:
# str

# %%
type(my_list1[-1])
# Out:
# int

# %%
my_list1[0].upper()
# Out:
# 'ONE'

# %%
my_list1
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
my_list1[1:]
# Out:
# ['two', 'three', 4, 5]

# %%
my_list1[1:4]
# Out:
# ['two', 'three', 4]

# %%
# CXoncatenation of list  and list 

my_list1 + [2, 3, 4]
# Out:
# ['one', 'two', 'three', 4, 5, 2, 3, 4]

# %%
my_list1
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list1[1:4] + my_list[0:2]
# Out:
# ['two', 'three', 4, 1, 2]

# %% [markdown]
# ### Basic list Methods

# %%
l1 = [1,2,3]

# %%
#append 

l1.append('append me !!') # There will be no output for this

# %%
l1
# Out:
# [1, 2, 3, 'append me !!']

# %%
type(l1)
# Out:
# list

# %%
demo_list = l1.append(34)

# %%
demo_list         # Thereb wont be any out put, it just alter the list. This append is like instruction.

# %%
type(demo_list)
# Out:
# NoneType

# %%
type(l1)
# Out:
# list

# %%
l1
# Out:
# [1, 2, 3, 'append me !!', 34]

# %%
x = 'hello worls'

# %%
type(x)
# Out:
# str

# %%
y = print('Hello world')
# Out:
# Hello world

# %%
type(y)
# Out:
# NoneType

# %%
# pop : Use to popout the item from the list
# By default it pop out the last on 

l1
# Out:
# [1, 2, 3, 'append me !!', 34]

# %%
l1.pop()
# Out:
# 34

# %%
l1
# Out:
# [1, 2, 3, 'append me !!']

# %%
l1
# Out:
# [1, 2, 3, 'append me !!']

# %%
op__pop_l1 = l1.pop()

# %%
op__pop_l1
# Out:
# 'append me !!'

# %% [markdown]
# * Note this pop is the reverse of append:
# * append: helps to add at end
# * pop : helps to remove the last one bydefault.
# * Note it also alters the original list

# %%
l1
# Out:
# [1, 2, 3]

# %%
lst = [1,2,3,4]

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.pop(0) # Give index
# Out:
# 1

# %%
lst
# Out:
# [2, 3, 4]

# %%
 new_list = ['a', 'e', 'x', 'b', 'c']

# %%
new_list
# Out:
# ['a', 'e', 'x', 'b', 'c']

# %%
new_list.reverse() # it doesnt give any output

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
# Sort
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
# Toget decending: first sort and reverse 
new_list.reverse()

# %%
new_list
# Out:
# ['x', 'e', 'c', 'b', 'a']

# %% [markdown]
# * important : none type

# %%
num = [1, 2 ,3 ,82]

# %%
num.sort()

# %%
num
# Out:
# [1, 2, 3, 82]

# %%
num.reverse()

# %%
num
# Out:
# [82, 3, 2, 1]

# %% [markdown]
# #### Nesting List

# %%
lst_1 = [1,2,3]
lst_2 = [4,5,6]
lst_3 = [7,8,9]

# %%
matrix = [lst_1, lst_2, lst_3] # This is two dime list

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[0][1]
# Out:
# 2

# %%
matrix[0][-2]
# Out:
# 2

# %%
matrix[2]
# Out:
# [7, 8, 9]

# %%
matrix[-2][-1]
# Out:
# 6

# %%
sample_list = [1,2.5,'hello',True,{'saji':'Value2'},{'K1':'Value1'}, [21,78,'Saji', 'Hello']]

# %%
sample_list
# Out:
# [1,
#  2.5,
#  'hello',
#  True,
#  {'saji': 'Value2'},
#  {'K1': 'Value1'},
#  [21, 78, 'Saji', 'Hello']]

# %%
type(sample_list)
# Out:
# list

# %%
type(sample_list[3])
# Out:
# bool

# %%
type(sample_list[4])
# Out:
# dict

# %%
sample_list[-1][-2]
# Out:
# 'Saji'

# %%
sample_list[-1][-2].upper()
# Out:
# 'SAJI'

# %%
sample_list[-1][-2].lower()
# Out:
# 'saji'

# %%
sample_list[-1][-2].capitalize()
# Out:
# 'Saji'

# %%
len(sample_list[-1][-2])
# Out:
# 4

# %%
sample_list[-1][-2] + ' ' + sample_list[-1][-1]
# Out:
# 'Saji Hello'

# %%
  sample_list
# Out:
# [1,
#  2.5,
#  'hello',
#  True,
#  {'saji': 'Value2'},
#  {'K1': 'Value1'},
#  [21, 78, 'Saji', 'Hello']]

# %% [markdown]
# ###  Exersice

# %%
new_lst = [12, ['32.87','name','by'], 45.1, 'Shreyas',['Machine Learning','RBPL','led', 'course'], 'instructor',[' '],'is' ]

# %%
new_lst
# Out:
# [12,
#  ['32.87', 'name', 'by'],
#  45.1,
#  'Shreyas',
#  ['Machine Learning', 'RBPL', 'led', 'course'],
#  'instructor',
#  [' '],
#  'is']

# %% [markdown]
# 1. Course name is ML
# 2. led by Shreyas
# 3. 87/12
# 4.

# %%
 new_lst[4][-1].capitalize() + new_lst[-2][0]
# Out:
# 'Course '

# %%
new_lst[4][-1].capitalize() + new_lst[-2][0] + new_lst[1][-2] + new_lst[-2][0] + new_lst[-1]  + new_lst[-2][0]+ new_lst[-4][0]
# Out:
# 'Course name is Machine Learning'

# %%
new_lst[1][0]
# Out:
# '32.87'

# %%
type(new_lst[1][0])
# Out:
# str

# %%
int(new_lst[1][0].split('.')[-1])/new_lst[0]
# Out:
# 7.25

# %%
# other way is 
new_lst[1][0]
# Out:
# '32.87'

# %%
new_lst[1][0][3:]
# Out:
# '87'

# %%
int(new_lst[1][0][3:])
# Out:
# 87

# %%
ls = 'string1 SAJI'

# %%
ls.split() #default it split from spaces
# Out:
# ['string1', 'SAJI']

# %%
ls
# Out:
# 'string1 SAJI'

# %%
ls.split('S')
# Out:
# ['string1 ', 'AJI']

# %%
prac_lst =[1,'Hai', 2.5,'Saji','32',3]

# %%
prac_lst
# Out:
# [1, 'Hai', 2.5, 'Saji', '32', 3]

# %% [raw]
# #prac_lst = [1, 'Hai', 2.5, 'Saji', '32', 3]
#
# # Find the index of '32' and replace it with 'M'
# #prac_lst[index_32] = 'M'
#
# #print(prac_lst)

# %%
prac_lst
# Out:
# [1, 'Hai', 2.5, 'Saji', '32', 3]

# %%
index_32 = prac_lst.index('32')

# %%
index_32
# Out:
# 4

# %%
 prac_lst[index_32] = 'M' # Remember list is mutable

# %%
prac_lst
# Out:
# [1, 'Hai', 2.5, 'Saji', 'M', 3]

# %%
print(prac_lst)
# Out:
# [1, 'Hai', 2.5, 'Saji', 'M', 3]

# %% [markdown]
# prac_list2 = [[98,[34.8,['hello world']],'Elon',[['Musk'],'Shreyas']], 'controls', ' ',404, 747]
#
# 1. 'HELLO Elon Musk'
# 2. do a division of any two numbers from prac_list2 and mulitply it with addition the other two numbers
# 3. replace 'Shreyas' with 'everyone'
# 4. 'Elon Musk controls everyone'

# %%
prac_list2 = [[98,[34.8,['hello world']],'Elon',[['Musk'],'Shreyas']], 'controls', ' ',404, 747]

# %%
len(prac_list2)
# Out:
# 5

# %%
prac_list2[0]
# Out:
# [98, [34.8, ['hello world']], 'Elon', [['Musk'], 'Shreyas']]

# %%
prac_list2[0][1]
# Out:
# [34.8, ['hello world']]

# %%
prac_list2[0][1][-1] # this is also a list look at the []
# Out:
# ['hello world']

# %%
prac_list2[0][1][-1][0]  # Now it become asingle string
# Out:
# 'hello world'

# %%
prac_list2[0][1][-1][0][:5]
# Out:
# 'hello'

# %%
prac_list2[0][1][-1][0][:6].upper() + prac_list2[0][2] + prac_list2[-3] + prac_list2[0][-1][0][0]
# Out:
# 'HELLO Elon Musk'

# %%
# Replace 'Shreyas' to 'Everyone'
prac_list2[0][-1][-1] = 'Everyone'

# %%
prac_list2
# Out:
# [[98, [34.8, ['hello world']], 'Elon', [['Musk'], 'Everyone']],
#  'controls',
#  ' ',
#  404,
#  747]

# %%
num
# Out:
# [82, 3, 2, 1]

# %%
num.index(3)
# Out:
# 1

# %%
num.count(3) # gives how many time 3 appears
# Out:
# 1
