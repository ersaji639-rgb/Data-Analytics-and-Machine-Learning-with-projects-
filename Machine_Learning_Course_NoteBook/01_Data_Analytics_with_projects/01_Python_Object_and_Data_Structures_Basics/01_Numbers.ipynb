# %% [markdown]
# ## Basic Arithmetic # for this type: ##                         Basic Arithmetic

# %%
# Addition 
# hash is a comment ( Wont be eecuted )  Anything you write

# %%
# Addition 

2+3
# Out:
# 5

# %%
# Multiplication 

9*6
# Out:
# 54

# %%
# Devision

2/3
# Out:
# 0.6666666666666666

# %%
# floor Division (Truncate the decimel)

19//4
# Out:
# 4

# %%
# Modulo (Gives remainder)

19%4
# Out:
# 3

# %%
# Power (2^0.5)

2**0.5
# Out:
# 1.4142135623730951

# %%
# Can use paranthesis to specify the order of operation (BODMAS)

2 + 10*10 + 13
# Out:
# 115

# %%
(2 + 10)*10 + 13
# Out:
# 133

# %%
(2 + 10) * (10 + 13)
# Out:
# 276
