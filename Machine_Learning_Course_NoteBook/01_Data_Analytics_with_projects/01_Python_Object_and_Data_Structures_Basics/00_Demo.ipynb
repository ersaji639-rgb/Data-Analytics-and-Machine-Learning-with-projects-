# %%
10/3
# Out:
# 3.3333333333333335

# %% [markdown]
# #### Press m for code cell to marker cell

# %% [markdown]
# #### Press y to convert the marker cell to code cell

# %%
33.2/2
# Out:
# 16.6

# %% [markdown]
# #### Order of execution is important and not the order of appearence.
