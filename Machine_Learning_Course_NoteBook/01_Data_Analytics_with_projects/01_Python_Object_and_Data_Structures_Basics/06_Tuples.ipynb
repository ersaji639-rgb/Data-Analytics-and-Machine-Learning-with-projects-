# %%
# Tuple
t = (1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 3

# %%
t1 = ('one',2)

# %%
t1[0]
# Out:
# 'one'

# %%
# slicing and concatination
t[0:2]
# Out:
# (1, 2)

# %%
#t.append('append me!!') Wont work  similarly, t.pop(),t.sort(), t.reverse() also oesnt work

# %%
#index 
t.index(2)
# Out:
# 1

# %%
t.count(2)
# Out:
# 1

# %%
# These two fns are not altering
