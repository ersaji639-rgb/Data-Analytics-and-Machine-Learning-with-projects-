# %% [markdown]
# ### Sets

# %%
x = set() # Empty set

# %%
x
# Out:
# set()

# %%
type(x)
# Out:
# set

# %%
x.add(1)

# %%
x
# Out:
# {1}

# %%
x.add(2)

# %%
x
# Out:
# {1, 2}

# %%
x.add('saji')

# %%
x
# Out:
# {1, 2, 'saji'}

# %%
x.add(1)

# %%
x
# Out:
# {1, 2, 'saji'}

# %%
x.add('hi')

# %%
x
# Out:
# {1, 2, 'hi', 'saji'}

# %%
l1 = [1,2,2,3,4,5,6,7,71,89,71,56] # List

# %%
# cast as set

# %%
set(l1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 56, 71, 89}

# %%
l2 = [1,2,2,3,4,5, 'hi', 'Saji',6,7,71,89,71,56,True] # List

# %%
l2
# Out:
# [1, 2, 2, 3, 4, 5, 'hi', 'Saji', 6, 7, 71, 89, 71, 56, True]

# %%
set(l2) # set doesnt accept bolean values
# Out:
# {1, 2, 3, 4, 5, 56, 6, 7, 71, 89, 'Saji', 'hi'}

# %% [markdown]
# ### Boolean
# * Comparision operator
# * Acts as a switch

# %%
1>2 # conparision
# Out:
# False

# %%
bias = True # this means we are turning on the bias

# %%
#True, False # acts like on off switch

# %% [markdown]
# ###  Comparision operators

# %%
# Equal 
2 == 2
# Out:
# True

# %%
1 == 2/2
# Out:
# True

# %%
1 == 3/5
# Out:
# False

# %%
1 == 3
# Out:
# False

# %%
# not equal to
2 != 1
# Out:
# True

# %%
1 != 1
# Out:
# False

# %%
x = 1 != 1

# %%
x
# Out:
# False

# %%
type(x)
# Out:
# bool

# %%
# Greater than 

2 > 1
# Out:
# True

# %%
# Greater than equal to 
1 >= 2
# Out:
# False

# %%
2 < 5
# Out:
# True

# %%
2 <= 5
# Out:
# True

# %% [markdown]
# ###  Chained Comparision operator

# %%
3 < 5 < 7
# Out:
# True

# %%
(3 < 5) and (5 < 7)  # above can be written as this
# Out:
# True

# %%
(1<5) or (2<1)
# Out:
# True

# %%
(1<5) and (2<1)
# Out:
# False

# %%
x = 5
print(1 < x < 10)     # True (x is between 1 and 10)
print(10 > x >= 5)    # True (x is less than 10 and greater than or equal to 5)
print(1 == x < 10)    # False (1 == 5 is False)
# Out:
# True
# True
# False

# %%
(1 < x) and (x < 10) # Without chaining
# Out:
# True

# %%
1 < x < 10 # with chaining in python
# Out:
# True

# %%
1 == 1 or 100 != 1
# Out:
# True
