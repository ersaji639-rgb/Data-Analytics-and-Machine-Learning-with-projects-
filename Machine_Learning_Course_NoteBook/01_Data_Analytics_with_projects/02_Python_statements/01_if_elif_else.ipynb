# %%
x = 5 + 2    # assignment + expression
print(x)     # function call
# Out:
# 7

# %%
if x > 10:
    print("x is greater than 10")
elif x == 10:
    print("x is 10")
else:
    print("x is less than 10")
# Out:
# x is less than 10

# %%
if 3 > 2: 
    print("it was true")
# Out:
# it was true

# %%
if 3 < 2: 
    print("it was false")

# %%
3 > 2
# Out:
# True

# %%
x = 3 < 2

# %%
if x: 
    print("it was true")
else:
    print("it was false")
# Out:
# it was false

# %% [markdown]
# ### Multiple Branches

# %%
x = input(' Enter Something here: ')
# Out:
#  Enter Something here:  Hello

# %%
x
# Out:
# 'Hello'

# %%
location  = input(' Enter your location here: ')
# Out:
#  Enter your location here:  Bank

# %%
location = location.lower()
location
# Out:
# 'bank'

# %%
if location == 'workshop':
    print(' Welcome to workshop') # this indendation/ whitespace is imp*. 
elif location == 'bank':  
    print ('Welcome to bank')
elif location == 'airport':
    print('Welcome to terminal')
else:
    print('Where are you?')
# Out:
# Welcome to bank

# %%
range(5)
# Out:
# range(0, 5)
