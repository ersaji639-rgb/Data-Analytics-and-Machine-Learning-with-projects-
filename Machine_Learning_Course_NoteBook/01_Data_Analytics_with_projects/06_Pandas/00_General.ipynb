# %% [markdown]
# Go through the documentation ---> API Reference

# %%
# Pandas is an opensourse library for data analytics. 
# It usesan exteremly power full table object called as Data frame systm, which iss built on top of numpy library. 
# computationaly efficient. 
# User friendly. 


# It can read an write data of large size. (Wide variety of formats) 
#


# Content 
# Series  and Data frames 
# Conditional filtering and Useful methods 
# Missing Data 
# Group by operatin 
# Combining Data frames 
# Text methods and time methods 
# input and output.

# %%
# series :
# A data structure in pandas that holds an arrays of info  along with "named index". 
# panda series  means : one-dimensional ndarray with axis labels.

# %%
# numpy array
#  index      Data 
# 0       23
# 1       25


# etc.

# %%
# Panda series: adds an labeled index

#eg: 
# labeled index      Data 
# USA      1176 
# Canada   1867


# etc

# %%
# Note* data is still stored in below 
# Numeric Index   Labeled index    Data
# 0                USA              2536
# 1                Canada           1254
