# %% [markdown]
# ### Time methods

# %% [markdown]
# ### Python Date time library

# %%
from datetime import datetime

# %%
my_year = 2025
my_month = 5
my_day = 11 
my_hour = 10
my_minute = 59
my_sec = 56

# %%
my_date_time = datetime(my_year,my_month,my_day,my_hour,my_minute,my_sec)

# %%
my_date_time.day
# Out:
# 11

# %%
my_date_time.minute
# Out:
# 59

# %%
my_date_time.isoweekday()
# Out:
# 7

# %%
my_date_time.timestamp()
# Out:
# 1746941396.0

# %%
my_date_time.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2025, week=19, weekday=7)

# %% [markdown]
# ### Pandas date time

# %%
import pandas as pd

# %%
pd.Series(['Nov 3, 2000','2000-01-01', None ])
# Out:
# 0    Nov 3, 2000
# 1     2000-01-01
# 2           None
# dtype: object

# %%
my_ser = pd.Series(['Nov 3, 2000','2000-01-01', None ])

# %%
my_ser
# Out:
# 0    Nov 3, 2000
# 1     2000-01-01
# 2           None
# dtype: object

# %%
my_ser[0]
# Out:
# 'Nov 3, 2000'

# %%
type(my_ser[0])
# Out:
# str

# %%
# the above type is string , how to convert it in to date tim object.

# %%
pd.to_datetime(my_ser)
# Out:
# 0   2000-11-03
# 1   2000-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
my_ser
# Out:
# 0    Nov 3, 2000
# 1     2000-01-01
# 2           None
# dtype: object

# %%
type(my_ser[0])
# Out:
# str

# %%
pd.to_datetime(my_ser)
# Out:
# 0   2000-11-03
# 1   2000-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
my_dt = pd.to_datetime(my_ser)

# %%
my_dt
# Out:
# 0   2000-11-03
# 1   2000-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
my_dt[0]
# Out:
# Timestamp('2000-11-03 00:00:00')

# %%
type(my_dt[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
sample_date = '31-12-2025'

# %%
pd.to_datetime(sample_date)
# Out:
# /tmp/ipykernel_1009598/1713164454.py:1: UserWarning: Parsing '31-12-2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(sample_date)
# Timestamp('2025-12-31 00:00:00')

# %%
sample_date1 = '10-12-2025'

pd.to_datetime(sample_date1)
# Out:
# Timestamp('2025-10-12 00:00:00')

# %%
# above gave wrong result. 
sample_date2 = '10-12-2025'

pd.to_datetime(sample_date2, dayfirst = True)
# Out:
# Timestamp('2025-12-10 00:00:00')

# %% [markdown]
# ###  Custom time string formatting

# %%
styled_date = '12&*^Dec))!@2025'

# %%
pd.to_datetime(styled_date,format = '%d&*^%b))!@%Y')
# Out:
# Timestamp('2025-12-12 00:00:00')

# %%
# check datetime pandas documentation.

# %%
styled_date1 = '12&*^12))!@2025'

# %%
pd.to_datetime(styled_date1,format = '%d&*^%m))!@%Y')
# Out:
# Timestamp('2025-12-12 00:00:00')

# %% [markdown]
# ### Data

# %%
sales = pd.read_csv('RetailSales_BeerWineLiquor.csv')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           340 non-null    object
#  1   MRTSSM4453USN  340 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.4+ KB

# %%
sales.head()
# Out:
#          DATE  MRTSSM4453USN
# 0  1992-01-01           1509
# 1  1992-02-01           1541
# 2  1992-03-01           1597
# 3  1992-04-01           1675
# 4  1992-05-01           1822

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           340 non-null    object
#  1   MRTSSM4453USN  340 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.4+ KB

# %%
sales.tail()
# Out:
#            DATE  MRTSSM4453USN
# 335  2019-12-01           6630
# 336  2020-01-01           4388
# 337  2020-02-01           4533
# 338  2020-03-01           5562
# 339  2020-04-01           5207

# %%
sales.iloc[0]
# Out:
# DATE             1992-01-01
# MRTSSM4453USN          1509
# Name: 0, dtype: object

# %%
sales.iloc[0]['DATE']
# Out:
# '1992-01-01'

# %%
type(sales.iloc[0]['DATE'])
# Out:
# str

# %%
# I need to convert

# %%
sales['DATE'] = pd.to_datetime(sales['DATE'])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           340 non-null    datetime64[ns]
#  1   MRTSSM4453USN  340 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.4 KB

# %%
sales
# Out:
#           DATE  MRTSSM4453USN
# 0   1992-01-01           1509
# 1   1992-02-01           1541
# 2   1992-03-01           1597
# 3   1992-04-01           1675
# 4   1992-05-01           1822
# ..         ...            ...
# 335 2019-12-01           6630
# 336 2020-01-01           4388
# 337 2020-02-01           4533
# 338 2020-03-01           5562
# 339 2020-04-01           5207
#
# [340 rows x 2 columns]

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           340 non-null    datetime64[ns]
#  1   MRTSSM4453USN  340 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.4 KB

# %%
sales.head()
# Out:
#         DATE  MRTSSM4453USN
# 0 1992-01-01           1509
# 1 1992-02-01           1541
# 2 1992-03-01           1597
# 3 1992-04-01           1675
# 4 1992-05-01           1822

# %%
#sales = sales.set_index('DATE')

# %%
#sales

# %%
sales
# Out:
#           DATE  MRTSSM4453USN
# 0   1992-01-01           1509
# 1   1992-02-01           1541
# 2   1992-03-01           1597
# 3   1992-04-01           1675
# 4   1992-05-01           1822
# ..         ...            ...
# 335 2019-12-01           6630
# 336 2020-01-01           4388
# 337 2020-02-01           4533
# 338 2020-03-01           5562
# 339 2020-04-01           5207
#
# [340 rows x 2 columns]

# %% [markdown]
# ### .dt method

# %%
sales['DATE'].dt.month
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 335    12
# 336     1
# 337     2
# 338     3
# 339     4
# Name: DATE, Length: 340, dtype: int64

# %%
sales['Month'] = sales['DATE'].dt.month

# %%
sales
# Out:
#           DATE  MRTSSM4453USN  Month
# 0   1992-01-01           1509      1
# 1   1992-02-01           1541      2
# 2   1992-03-01           1597      3
# 3   1992-04-01           1675      4
# 4   1992-05-01           1822      5
# ..         ...            ...    ...
# 335 2019-12-01           6630     12
# 336 2020-01-01           4388      1
# 337 2020-02-01           4533      2
# 338 2020-03-01           5562      3
# 339 2020-04-01           5207      4
#
# [340 rows x 3 columns]

# %%
# check pandas.dt method ocumentation

# %%
sales['DATE'].dt.year
# Out:
# 0      1992
# 1      1992
# 2      1992
# 3      1992
# 4      1992
#        ...
# 335    2019
# 336    2020
# 337    2020
# 338    2020
# 339    2020
# Name: DATE, Length: 340, dtype: int64

# %%
sales['DATE'].dt.day
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 335    1
# 336    1
# 337    1
# 338    1
# 339    1
# Name: DATE, Length: 340, dtype: int64

# %%
sales['DATE'].dt.dayofyear
# Out:
# 0        1
# 1       32
# 2       61
# 3       92
# 4      122
#       ...
# 335    335
# 336      1
# 337     32
# 338     61
# 339     92
# Name: DATE, Length: 340, dtype: int64

# %%
sales['Year'] = sales['DATE'].dt.year

# %%
sales
# Out:
#           DATE  MRTSSM4453USN  Month  Year
# 0   1992-01-01           1509      1  1992
# 1   1992-02-01           1541      2  1992
# 2   1992-03-01           1597      3  1992
# 3   1992-04-01           1675      4  1992
# 4   1992-05-01           1822      5  1992
# ..         ...            ...    ...   ...
# 335 2019-12-01           6630     12  2019
# 336 2020-01-01           4388      1  2020
# 337 2020-02-01           4533      2  2020
# 338 2020-03-01           5562      3  2020
# 339 2020-04-01           5207      4  2020
#
# [340 rows x 4 columns]

# %%
sales.groupby('Year').mean()['MRTSSM4453USN'].plot()
# Out:
# <Axes: xlabel='Year'>

# %%
# To cheack wee end how the sales happening ( u should have daily data) : conditional filtering Day = 5 or day = 6 and plot.

# %%
sales['Day'] = sales['DATE'].dt.day_of_week

# %%
sales.head()
# Out:
#         DATE  MRTSSM4453USN  Month  Year  Day
# 0 1992-01-01           1509      1  1992    2
# 1 1992-02-01           1541      2  1992    5
# 2 1992-03-01           1597      3  1992    6
# 3 1992-04-01           1675      4  1992    2
# 4 1992-05-01           1822      5  1992    4

# %%
(sales['Day'] == 5 ) | (sales['Day'] == 6)
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 335     True
# 336    False
# 337     True
# 338     True
# 339    False
# Name: Day, Length: 340, dtype: bool

# %%
sales[(sales['Day'] == 5 ) | (sales['Day'] == 6)]
# Out:
#           DATE  MRTSSM4453USN  Month  Year  Day
# 1   1992-02-01           1541      2  1992    5
# 2   1992-03-01           1597      3  1992    6
# 7   1992-08-01           1862      8  1992    5
# 10  1992-11-01           1831     11  1992    6
# 16  1993-05-01           1796      5  1993    5
# ..         ...            ...    ...   ...  ...
# 329 2019-06-01           5011      6  2019    5
# 332 2019-09-01           4680      9  2019    6
# 335 2019-12-01           6630     12  2019    6
# 337 2020-02-01           4533      2  2020    5
# 338 2020-03-01           5562      3  2020    6
#
# [98 rows x 5 columns]

# %%
weekend_sales = sales[(sales['Day'] == 5 ) | (sales['Day'] == 6)][['Day','MRTSSM4453USN']]
weekend_sales.groupby('Day').mean()['MRTSSM4453USN'].plot()
# Out:
# <Axes: xlabel='Day'>

# %%
weekend_sales
# Out:
#      Day  MRTSSM4453USN
# 1      5           1541
# 2      6           1597
# 7      5           1862
# 10     6           1831
# 16     5           1796
# ..   ...            ...
# 329    5           5011
# 332    6           4680
# 335    6           6630
# 337    5           4533
# 338    6           5562
#
# [98 rows x 2 columns]
