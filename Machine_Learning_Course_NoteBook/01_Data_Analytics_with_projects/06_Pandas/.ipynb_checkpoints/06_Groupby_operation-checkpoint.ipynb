# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mpg.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
 # first four

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# in above horse power have string (object)

# %%
df['origin']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %%
df['origin'].count()
# Out:
# 398

# %%
df['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 393     86
# 394     52
# 395     84
# 396     79
# 397     82
# Name: horsepower, Length: 398, dtype: object

# %%
df['horsepower'][0] # it is a string
# Out:
# '130'

# %%
# how to convert the data type  as int 
pd.to_numeric(df['horsepower'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # how to convert the data type  as int
# ----> 2 pd.to_numeric(df['horsepower'])
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/tools/numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
int('138')

# %%
df['horsepower'].unique()

# %%
df['horsepower'] == '?'

# %%
df[df['horsepower'] == '?']

# %%
df.head()

# %%
df['horsepower'].replace('?','0') # iam repalcing the question make to df

# %%
df['horsepower']= df['horsepower'].replace('?','0') # iam repalcing the question make to df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['horsepower'] = pd.to_numeric(df['horsepower']) # chnge the ata type
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['horsepower'] = pd.to_numeric(df['horsepower']) # chnge the ata type
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/tools/numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
df.info()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.groupby('model_year').max()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model_year
# 70          27.0          8         455.0         97    4732          20.5
# 71          35.0          8         400.0          ?    5140          20.5
# 72          28.0          8         429.0         97    4633          23.5
# 73          29.0          8         455.0         95    4997          21.0
# 74          32.0          8         350.0          ?    4699          21.0
# 75          33.0          8         400.0         98    4668          21.0
# 76          33.0          8         351.0         95    4380          22.2
# 77          36.0          8         400.0         98    4335          19.0
# 78          43.1          8         318.0         97    4080          21.5
# 79          37.3          8         360.0         90    4360          24.8
# 80          46.6          6         225.0          ?    3381          23.7
# ...

# %%
# Note in above for the name max will be in alphebatical, it is taking 
# groupby is used mainly for numerics. 
# you can drop name if u want.

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df =    df[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model_year']]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70

# %%
df.groupby('model_year').max()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration
# model_year
# 70          27.0          8         455.0         97    4732          20.5
# 71          35.0          8         400.0          ?    5140          20.5
# 72          28.0          8         429.0         97    4633          23.5
# 73          29.0          8         455.0         95    4997          21.0
# 74          32.0          8         350.0          ?    4699          21.0
# 75          33.0          8         400.0         98    4668          21.0
# 76          33.0          8         351.0         95    4380          22.2
# 77          36.0          8         400.0         98    4335          19.0
# 78          43.1          8         318.0         97    4080          21.5
# 79          37.3          8         360.0         90    4360          24.8
# 80          46.6          6         225.0          ?    3381          23.7
# ...

# %%
df.groupby('model_year').describe() # it gives all the statistical info
# Out:
#              mpg                                                          \
#            count       mean       std   min     25%    50%     75%   max
# model_year
# 70          29.0  17.689655  5.339231   9.0  14.000  16.00  22.000  27.0
# 71          28.0  21.250000  6.591942  12.0  15.500  19.00  27.000  35.0
# 72          28.0  18.714286  5.435529  11.0  13.750  18.50  23.000  28.0
# 73          40.0  17.100000  4.700245  11.0  13.000  16.00  20.000  29.0
# 74          27.0  22.703704  6.420010  13.0  16.000  24.00  27.000  32.0
# 75          30.0  20.266667  4.940566  13.0  16.000  19.50  23.000  33.0
# 76          34.0  21.573529  5.889297  13.0  16.750  21.00  26.375  33.0
# 77          28.0  23.375000  6.675862  15.0  17.375  21.75  30.000  36.0
# 78          36.0  24.061111  6.898044  16.2  19.350  20.70  28.000  43.1
# 79          29.0  25.093103  6.794217  15.5  19.200  23.90  31.800  37.3
# 80          29.0  33.696552  7.037983  19.1  29.800  32.70  38.100  46.6
# ...

# %%
df.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %% [markdown]
# ### Multiple column
# we can use groupby for multiple column as well

# %%
df.groupby(['model_year','cylinders']).mean() # passing col as a list
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
#            6          19.000000    212.250000  2917.125000     15.687500
# ...

# %%
df1 = df.groupby(['model_year','cylinders']).mean() # passing col as a list

# %%
df1
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
#            6          19.000000    212.250000  2917.125000     15.687500
# ...

# %%
df1.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
# above is a list of tuples

# %%
df1.columns
# Out:
# Index(['mpg', 'displacement', 'weight', 'acceleration'], dtype='object')

# %%
df1.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
df1.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
# To grab 
df1.loc[(74,6)]
# Out:
# mpg               17.857143
# displacement     230.428571
# weight          3320.000000
# acceleration      16.857143
# Name: (74, 6), dtype: float64

# %%
df1
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
#            6          19.000000    212.250000  2917.125000     15.687500
# ...

# %%
df1.sort_index(level ='cylinders')
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 72         3          19.000000     70.000000  2330.000000     13.500000
# 73         3          18.000000     70.000000  2124.000000     13.500000
# 77         3          21.500000     80.000000  2720.000000     13.500000
# 80         3          23.700000     70.000000  2420.000000     12.500000
# 70         4          25.285714    107.000000  2292.571429     16.000000
# 71         4          27.461538    101.846154  2056.384615     16.961538
# 72         4          23.428571    111.535714  2382.642857     17.214286
# 73         4          22.727273    109.272727  2338.090909     17.136364
# 74         4          27.800000     96.533333  2151.466667     16.400000
# 75         4          25.250000    114.833333  2489.250000     15.833333
# 76         4          26.766667    106.333333  2306.600000     16.866667
# 77         4          29.107143    106.500000  2205.071429     16.064286
# ...

# %%
df1.sort_index(level ='cylinders', ascending = False)# to make decending
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 81         8          26.600000    350.000000  3725.000000     19.000000
# 79         8          18.630000    321.400000  3862.900000     15.400000
# 78         8          19.050000    300.833333  3563.333333     13.266667
# 77         8          16.000000    335.750000  4177.500000     13.662500
# 76         8          14.666667    324.000000  4064.666667     13.222222
# 75         8          15.666667    330.500000  4108.833333     13.166667
# 74         8          14.200000    315.200000  4438.400000     14.700000
# 73         8          13.200000    365.250000  4279.050000     12.250000
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 71         8          13.428571    371.714286  4537.714286     12.214286
# 70         8          14.111111    367.555556  3940.055556     11.194444
# 82         6          28.333333    225.000000  2931.666667     16.033333
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70

# %%
df.groupby('model_year').agg({'mpg':['median','mean','max'],
                              'horsepower':['std','max','mean','var']}) # in describe we can be more specific
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.groupby('model_year').agg({'mpg':['median','mean','max'],
#       2                               'horsepower':['std','max','mean','var']}) # in describe we can be more specific
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
# ...

# %%
df.groupby('model_year').apply(lambda x:2*x)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    36.0         16         614.0     130130    7008          24.0
# 1    30.0         16         700.0     165165    7386          23.0
# 2    36.0         16         636.0     150150    6872          22.0
# 3    32.0         16         608.0     150150    6866          24.0
# 4    34.0         16         604.0     140140    6898          21.0
# ..    ...        ...           ...        ...     ...           ...
# 393  54.0          8         280.0       8686    5580          31.2
# 394  88.0          8         194.0       5252    4260          49.2
# 395  64.0          8         270.0       8484    4590          23.2
# 396  56.0          8         240.0       7979    5250          37.2
# 397  62.0          8         238.0       8282    5440          38.8
#
#      model_year
# 0           140
# 1           140
# 2           140
# 3           140
# 4           140
# ..          ...
# 393         164
# ...

# %%
# pandas (data frame)  are used for tabular data 
# tabular data are foundataional data for anything  
# almost all kind of cata can be transformed into tabular data 
# eg Sound : freq u can put in to table
# images pixel, in to table
